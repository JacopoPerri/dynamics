# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/elisa/miniconda3/envs/fermipy/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/elisa/miniconda3/envs/fermipy/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/elisa/miniconda3/envs/fermipy/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/elisa/miniconda3/envs/fermipy/lib/python3.9/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/elisa/miniconda3/envs/fermipy/lib/python3.9/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/elisa/miniconda3/envs/fermipy/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
def r_int_to_cm(r):
    return r*5.11e12
def m_int_to_g(M):
    return M*2e33
def t_int_to_s(t):
    return t*1e6
def v_int_to_cms(v):
    return v*5.11e6

# %%
data = pd.read_csv('2b_output.txt', sep=' ', header=None, names=range(7))
data.columns = ['m','x','y','z','vx','vy','vz']

# %%
print(data)
# Out:
#                     m             x             y    z           vx  \
# 0            2.000000           NaN           NaN  NaN          NaN
# 1            0.000002           NaN           NaN  NaN          NaN
# 2            1.000000  1.584148e-01  4.286925e-03  0.0  1061.898600
# 3      1000000.000000 -1.584148e-07 -4.286925e-09  0.0    -0.001062
# 4            2.000000           NaN           NaN  NaN          NaN
# ...               ...           ...           ...  ...          ...
# 21719  1000000.000000 -1.555388e-07  2.237448e-09  0.0    -0.001167
# 21720        2.000000           NaN           NaN  NaN          NaN
# 21721        0.000545           NaN           NaN  NaN          NaN
# 21722        1.000000  1.574372e-01  1.999844e-03  0.0  1098.166039
# 21723  1000000.000000 -1.574372e-07 -1.999844e-09  0.0    -0.001098
#
#                 vy   vz
# 0              NaN  NaN
# 1              NaN  NaN
# 2      2526.424223  0.0
# 3        -0.002526  0.0
# 4              NaN  NaN
# ...            ...  ...
# 21719    -0.002527  0.0
# 21720          NaN  NaN
# 21721          NaN  NaN
# 21722  2527.146730  0.0
# 21723    -0.002527  0.0
#
# [21724 rows x 7 columns]

# %%
time_rows = data[data.index % 4 -1 == 0]
times = (time_rows['m'])

m1_rows = data[data.index % 4 -2 == 0]
m2_rows = data[data.index % 4 -3 == 0]

# %%
color = times
plt.scatter(m1_rows['x'],m1_rows['y'], c=color,  marker='.', alpha=0.5)
#plt.plot(m1_rows['x'],m1_rows['y'],  marker='.', alpha=1)

plt.scatter(m2_rows['x'],m2_rows['y'], c=color, s=0.1, alpha=1)
plt.xlim(-0.2,0.3)
plt.ylim(-0.2,0.3)
plt.colorbar()

# %%
x1 = np.array(m1_rows['x'])
x2 = np.array(m2_rows['x'])
y1 = np.array(m1_rows['y'])
y2 = np.array(m2_rows['y'])
aper = min(np.sqrt((x1-x2)**2+(y1-y2)**2))
aapo = max(np.sqrt((x1-x2)**2+(y1-y2)**2))
print(aapo)
# Out:
# 0.2832124078561814

# %%
print((-aper+aapo)/(aper+aapo))

#print(r_int_to_cm((aper+aapo))
# Out:
# 0.44721436595853553

# %%
M = m1_rows.iloc[0]['m'] + m2_rows.iloc[0]['m']
mu = (m1_rows.iloc[0]['m'] * m2_rows.iloc[0]['m'])/M

# %%
def theta(x1,y1,x2,y2):
    return np.arctan((y1-y2)**2/(x1-x2)**2)
def r(x1, y1, x2, y2):
    return (x1-x2)**2 + (y1-y2)**2

# %%
vtheta = theta(m1_rows['x'],m1_rows['y'],m2_rows['x'],m2_rows['y'])
vr = r(m1_rows['x'],m1_rows['y'],m2_rows['x'],m2_rows['y'])

# %%
vir = v_int_to_cms(r(0.23, 0, -0.23, 0))
print(vir)
# Out:
# 1081276.0

# %%
sep = r_int_to_cm(r(0.9700436,  -0.24308753,  -0.9700436,   0.24308753))
print(sep/7e10)
# Out:
# 292.0222308775986
